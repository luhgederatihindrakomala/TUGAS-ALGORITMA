# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
nama_40 = input('nama')
nim_40 = input('nim')
kelas_40 = input('kelas')
print('siap mengerjakan tugas 1 ALGORITMA dan STRUKTUR DATA')
# Out:
# nama Ratih Indra
# nim 2308541040
# kelas A
# siap mengerjakan tugas 1 ALGORITMA dan STRUKTUR DATA

# %%
harga_jual_40 = input("Berapakah harga jual barang tersebut? ")
harga_beli_40 = input("Berapakah harga beli barang tersebut? ")
keuntungan_40 = int(harga_jual_40) - int(harga_beli_40)
print("keuntungan yang diperoleh adalah" + str(keuntungan_40))
# Out:
# Berapakah harga jual barang tersebut?  75000
# Berapakah harga beli barang tersebut?  50000
# keuntungan yang diperoleh adalah25000

# %%
panjang_balok_40 = input("Berapa panjang balok itu? ")
lebar_balok_40 = input ("Berapa lebar balok itu? ")
tinggi_balok_40 = input ("Berapa tinggi balok itu? ")
volume_balok_40 = int(panjang_balok_40) * int(lebar_balok_40) * int(tinggi_balok_40)
print("jadi volume balok tersebut adalah" + str(volume_balok_40))
# Out:
# Berapa panjang balok itu?  12
# Berapa lebar balok itu?  10
# Berapa tinggi balok itu?  5
# jadi volume balok tersebut adalah600

# %%
lebar_suatu_persegi_panjang_40 = input("masukkan lebar persegi panjang")
panjang_suatu_persegi_panjang_40 = input("masukkan panjang persegi panjang")
keliling_persegi_panjang_40 = 2 * (int(panjang_suatu_persegi_panjang_40) + int(lebar_suatu_persegi_panjang_40))
print("maka keliling persegi panjang tersebut adalah" + str(keliling_persegi_panjang_40))
# Out:
# masukkan lebar persegi panjang 2
# masukkan panjang persegi panjang 3
# maka keliling persegi panjang tersebut adalah10

# %%
percepatan_suatu_benda_40 = input("isi percepatan bendanya") 
massa_benda_40 = input("masukkan massa bendanya") 
gaya_benda_40= int(percepatan_suatu_benda_40) * int(massa_benda_40)
print("dapat disimmpulkan gaya benda tersebut ialah" + str(gaya_benda_40))
# Out:
# isi percepatan bendanya 2
# masukkan massa bendanya 5
# dapat disimmpulkan gaya benda tersebut ialah10

# %%
x_40 = 21
y_40 = -21
print(x > y)
print(x < y)
# Out:
# True
# False

# %%
nilai_anda_40 = float(input("masukkan nilai anda"))
if nilai_anda_40 <75 :
    print("anda dinyatakan tidak lulus seleksi")
if nilai_anda_40 >=75 :
    print("anda dinyatakan lulus seleksi")
print("nantikan info seleksi selanjutnya ya")
# Out:
# masukkan nilai anda 90
# anda dinyatakan lulus seleksi
# nantikan info seleksi selanjutnya ya

# %%
berat_badan_40 = float(input("berapa berat badan anda?"))
kg_atau_gram_40 = input("berat dalam kg atau dalam gram")
if kg_atau_gram_40.upper() == 'KG':
    berat_badan_40 = berat_badan_40 * 1000
    print("berat anda " + str(berat_badan_40) + " gram ")
elif kg_atau_gram_40.upper() == 'GRAM':
    berat_badan_40 = berat_badan_40/1000
    print(f"berat anda adalah {berat_badan_40} kg")
# Out:
# berapa berat badan anda? 52
# berat dalam kg atau dalam gram kg
# berat anda 52000.0 gram

# %%
print("ungkap kepribadian anda dengan menjawab yes or no")
print("apakah anda suka konser?")
kepribadian_anda_40 = input("jawaban anda")
if kepribadian_anda_40 == "yes":
    print("anda kemungkinan ekstrovert")
elif kepribadian_anda_40 == "no":
    print("anda kemungkinan introvert")
else:
    print("masukkan anda tidak valid")
print("apakah anda lebih memilih memasak daripada membeli makanan cepat saji?")
kepribadian_anda_40 = input("jawaban anda")
if kepribadian_anda_40 == "yes":
    print("anda kemungkinan ekstrovert")
elif kepribadian_anda_40 == "no":
    print("anda kemungkinan introvert")
else:
    print("masukkan anda kurang sesuai")
print("apakah anda lebih suka belajar individu atau kelompok?")
kepribadian_anda_40 = input("jawaban anda")
if kepribadian_anda_40 == "yes":
    print("anda kemungkinan introvert")
elif kepribadian_anda_40 == "no":
    print("anda kemungkinan seorang ekstrovert") 
else:
    print("data yang anda masukkan salah")
print("apakah kamu nyaman berada dikeramaian?")
kepribadian_anda_40 = input("jawaban anda")
if kepribadian_anda_40 == "yes":
    print("anda kemungkinan seorang yang ekstrovert")
elif kepribadian_anda_40 == "no":
    print("anda kemungkinan introvert")
else:
    print("kurang tepat")
print("terima kasih sudah mencoba cek kepribadian ini")
# Out:
# ungkap kepribadian anda dengan menjawab yes or no
# apakah anda suka konser?
# jawaban anda yes
# anda kemungkinan ekstrovert
# apakah anda lebih memilih memasak daripada membeli makanan cepat saji?
# jawaban anda yes
# anda kemungkinan ekstrovert
# apakah anda lebih suka belajar individu atau kelompok?
# jawaban anda yes
# anda kemungkinan introvert
# apakah kamu nyaman berada dikeramaian?
# jawaban anda yes
# anda kemungkinan seorang yang ekstrovert
# terima kasih sudah mencoba cek kepribadian ini

# %%
print("hai,apa kabarmu hari ini?baik atau buruk?")
kabar_40 = input("kabar")
if kabar_40 == "baik":
    print("wah,syukurlah") 
else:
    print("tetap semangat menjalani harimu yaaaa, jangan pantang semangat")
print("ayo kita bermain tebak-tebakan")
tebak_aku_40 = input("setuju atau tidak jika kita bermain?")
if tebak_aku_40 == "setuju":
    print("yeyyy,simak baik-baik pertanyaannya yaa")
    print("lele lele apa yang bisa terbang?")
    tebak_aku_40 = input("ayo apaa hayoo")
    if tebak_aku_40 == "lelelawar":
        print("hahhhh,kok bisa tau si")
    else:
        print("jawaban kamu salah, tebak lagi dongg")
        tebak_aku_40 = input("menurut kamu apa jawabannya?")
    if tebak_aku_40 == "lelelawar":
        print("dalam 2 kali kesempatan kamu bisa menebaknyaa, luar biasa")
    else:
        print("ayoo coba tebak lagi")
        jawaban_40 = input("kira-kira apaa")
        if tebak_aku_40 == "lelelawar":
            print("di kesempatan terakhir akhirnya bisa ditebak sungguh hebat")
        else:
            print("yahhhh, jawaban kamu masih salah")
            print("mau di spill ga nih jawabannya?")
            jawaban_40 = input("mau atau tidak")
        if jawaban_40 == "mau":
            print("jadi,jawabannya itu lelelawar")
        elif jawaban_40 == "tidak":
            print("oke,nanti coba cari tau ya")
        else:
            print("bukan ini")
elif tebak_aku_40 == "tidak":
    print("oke,kita bisa bermain lain kali.tetap semangat yaa")
else:
    print("masukkan kurang sesuai")
print("semoga bisa membuatmu tersenyum")
# Out:
# hai,apa kabarmu hari ini?baik atau buruk?
# kabar baik
# wah,syukurlah
# ayo kita bermain tebak-tebakan
# setuju atau tidak jika kita bermain? setuju
# yeyyy,simak baik-baik pertanyaannya yaa
# lele lele apa yang bisa terbang?
# ayo apaa hayoo lebang
# jawaban kamu salah, tebak lagi dongg
# menurut kamu apa jawabannya? leleterbang
# ayoo coba tebak lagi
# kira-kira apaa leyap
# yahhhh, jawaban kamu masih salah
# mau di spill ga nih jawabannya?
# mau atau tidak mau
# jadi,jawabannya itu lelelawar
# semoga bisa membuatmu tersenyum

# %%
print("berapakah kecepatannya?")
jarak_40 = input("jarak(km): ")
waktu_40 = input("waktu(menit): ")
kecepatan_40 = int(jarak_40) * int(waktu_40)
print("jadi kecepatannya adalah " + str(kecepatan_40))
# Out:
# berapakah kecepatannya?
# jarak(km):  2
# waktu(menit):  20
# jadi kecepatannya adalah 40

# %%
print("terima kasih")
# Out:
# terima kasih
