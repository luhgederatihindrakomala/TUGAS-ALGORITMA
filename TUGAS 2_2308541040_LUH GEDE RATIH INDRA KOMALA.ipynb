# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
motor_40 = input ("berapa jumlah motor anda? ")
mobil_40 = input ("berapa jumlah mobil anda? ")
jumlah_40 = float(motor_40) + float(mobil_40)
print("jumlah kendaraanmu adalah " + str(jumlah_40))
# Out:
# berapa jumlah motor anda?  2
# berapa jumlah mobil anda?  1
# jumlah kendaraanmu adalah 3.0

# %%
waktu_kampus_40 =  input("berapa jam anda belajar di kampus? ")
waktu_rumah_40 = input("berapa jam anda belajar di rumah? ")
jumlah_40 = float(waktu_kampus_40) + float(waktu_rumah_40)
print("jumlah waktu belajar anda adalah "+ str(jumlah_40))
# Out:
# berapa jam anda belajar di kampus?  6
# berapa jam anda belajar di rumah?  4
# jumlah waktu belajar anda adalah 10.0

# %%
sks1_40 = input("isikan dengan sks semester 1")
sks2_40 = input("isikan dengan sks semester 2")
total_40 = float(sks1_40) + float(sks2_40)
print("total sks selama 2 semester adalah "+ str(total_40))
# Out:
# isikan dengan sks semester 1 21
# isikan dengan sks semester 2 19
# total sks selama 2 semester adalah 40.0

# %%
tempat_40 = "pantai kuta"
prestasi_40 = 'salah satu pantai terkenal di dunia'
jenis_destinasi_40 = 'wisata alam'
lokasi_40 = 'bali'
print(tempat_40 + ' adalah ' + prestasi_40 + ' sebagai destinasi ' + jenis_destinasi_40 + ' di '+ lokasi_40 + '.')
# Out:
# pantai kuta adalah salah satu pantai terkenal di dunia sebagai destinasi wisata alam di bali.

# %%
makanan_daerah_40 = "Bika Ambon"
asal_40 = 'Medan'
ciri_khas_40 = "berwarna kuning dan memiliki rongga"
print(makanan_daerah_40 + ' ialah makanan khas ' + asal_40 + ' yang memiliki ciri khas ' + ciri_khas_40 + '.')
# Out:
# Bika Ambon ialah makanan khas Medan yang memiliki ciri khas berwarna kuning dan memiliki rongga.

# %%
pahlawan_40 = "R A Kartini"
gender_40 = 'wanita'
asal_40 = 'Jepara'
jasa_40 = 'memperjuangkan emansipasi wanita'
dampak_40 = 'hari kelahiran beliau diperingati sebagai hari kartini'
print(f'{pahlawan_40} merupakan pejuang {gender_40} yang berasal dari {asal_40}. Beliau {jasa_40}, sehingga {dampak_40}.')
# Out:
# R A Kartini merupakan pejuang wanita yang berasal dari Jepara. Beliau memperjuangkan emansipasi wanita, sehingga hari kelahiran beliau diperingati sebagai hari kartini.

# %%
karya_sastra_40 = 'Puisi'
pengarang_40 = 'Sapardi Djoko Darmono'
judul_40 = 'Hujan Bulan Juni'
makna_40 = 'hujan yang turun di bumi mengisyaratkan kelembutan cinta' 
print(f'{karya_sastra_40} karya {pengarang_40} berjudul "{judul_40}" menceritakan {makna_40}.')
# Out:
# Puisi karya Sapardi Djoko Darmono berjudul "Hujan Bulan Juni" menceritakan hujan yang turun di bumi mengisyaratkan kelembutan cinta.

# %%
nama_40 = "Bobo"
gender_40 = 'perempuan'
kebiasaan_40 = 'menggerutu'
waktu_40 = 'ketika ditegur'
print(f"{nama_40} merupakan seorang {gender_40} yang memiliki kebiasaan {kebiasaan_40} {waktu_40}.")
# Out:
# Bobo merupakan seorang perempuan yang memiliki kebiasaan menggerutu ketika ditegur.

# %%
nama_penyakit_40 = "maag"
sistem_organ_tubuh_40 = 'sistem pencernaan'
terdampak_40 = 'pelajar'
rentang_40 = 'mahasiswa'
print(f"{nama_penyakit_40} merupakan penyakit {sistem_organ_tubuh_40} yang sering menyerang {terdampak_40} hingga {rentang_40}.")
# Out:
# maag merupakan penyakit sistem pencernaan yang sering menyerang pelajar hingga mahasiswa.

# %%
sarkasme_40 = 'setiap mata kuliah adalah bab baru di sebuah buku yang berhalaman tanpa batas'
print(sarkasme_40[26:-10])
# Out:
# bab baru di sebuah buku yang berhalaman t

# %%
kutipan_40 = '“Dirahasiakannya rintik rindunya kepada pohon berbunga itu” dikutip dari hujan bulan juni'
print(kutipan_40[17:-11])
# Out:
# rintik rindunya kepada pohon berbunga itu” dikutip dari hujan

# %%
lagu_40 =  "lagu Rewrite The Star menceritakan tentang dua orang yang saling mencintai namun dihadapkan dengan berbagai rintangan." 
print(lagu_40[3:-1:2])
# Out:
# uRwieTeSa ecrtkntnagdaoagyn aigmnitinmndhdpa egnbraa itna

# %%
kartun_40 = 'upin ipin masih menjadi animasi yang disukai anak-anak'
print(kartun_40[3:])
print(kartun_40[:2:-5])
# Out:
# n ipin masih menjadi animasi yang disukai anak-anak
# kkiiaa ninn

# %%
aktor_40 = 'saat ini Lee Do Hyun menjadi aktor yang menarik perhatian berkat film exuma'
print(len(aktor_40))
# Out:
# 75

# %%
aktor_40.upper()
# Out:
# 'SAAT INI LEE DO HYUN MENJADI AKTOR YANG MENARIK PERHATIAN BERKAT FILM EXUMA'

# %%
aktor_40.lower()
# Out:
# 'saat ini lee do hyun menjadi aktor yang menarik perhatian berkat film exuma'

# %%
aktor_40.find('perhatian')
# Out:
# 48

# %%
sayur_40 = 'Brokoli adalah sayur yang mengandung vitamin A'
print('brokoli' in sayur_40)
# Out:
# False

# %%
sayur_40.replace('Brokoli','Wortel')
# Out:
# 'Wortel adalah sayur yang mengandung vitamin A'

# %%
merk_40 = 'Dear Lala merupakan shade lipglow terpopuler dari Dear Me'
print(merk_40[7:])
# Out:
# la merupakan shade lipglow terpopuler dari Dear Me

# %%
sisi_kubus_40 = 6
sisi_tabung_40 = 3
print(sisi_kubus_40 > 4 and sisi_tabung_40 < 4)
# Out:
# True

# %%
kaki_anjing_40 = 4
kaki_angsa_40 = 2
print(kaki_anjing_40 < 5 or kaki_angsa_40 < 3)
# Out:
# True

# %%
roda_sepeda_40 = 2
roda_bajai_40 = 3
roda_mobil_40 = 4
print(roda_sepeda_40 < 3 or roda_bajai_40 < 6 or roda_mobil_40 > 8)
# Out:
# True

# %%
print(not (roda_sepeda_40 < 1 and roda_bajai_40 > 4 and roda_mobil_40 < 3))
# Out:
# True

# %%
a = 12==11
print(a)
a = 12>11
print(a)
a = 11<=12
print(a)
a = 11<12
print(a)
a = 11>=12
print(a)
# Out:
# False
# True
# True
# True
# False

# %%
x = 7 != 8
print(x)
x = 7 == 8
print(x)
x = 8 < 7
print(x)
x = 7 >= 8
print(x)
x = 7 <= 8
print(x)
x = 8 > 7
print(x)
x = 8 < 7
print(x)
# Out:
# True
# False
# False
# False
# True
# True
# False

# %%
print(3-9)
print(3+9)
print(3/9)
print(3//9)
print(3%9)
print(3*9)
print(3**9)
# Out:
# -6
# 12
# 0.3333333333333333
# 0
# 3
# 27
# 19683

# %%
x=7
x+=5
print(x)
x-=3
print(x)
x/=9
print(x)
x*=6
print(x)
x//=2
print(x)
x**=5
print(x)
x%=2
print(x)
# Out:
# 12
# 9
# 1.0
# 6.0
# 3.0
# 243.0
# 1.0

# %%
warna_40 = 'Darah berwarna merah'
print(len(warna_40))
# Out:
# 20

# %%
warna_40.lower()
# Out:
# 'darah berwarna merah'

# %%
warna_40.upper()
# Out:
# 'DARAH BERWARNA MERAH'

# %%
warna_40.find('merah')
# Out:
# 15

# %%
warna_40.find('darah')
# Out:
# -1

# %%
warna_40.replace('Darah','Cabai')
# Out:
# 'Cabai berwarna merah'

# %%
warna_40.replace('cabai','darah')
# Out:
# 'Darah berwarna merah'

# %%
print('darah' in warna_40)
# Out:
# False

# %%
hari_40 = 'sabtu dan minggu adalah hari yang paling ditunggu-tunggu'
print(hari_40[11:-11])
# Out:
# inggu adalah hari yang paling ditu
